# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
a1=pd.Series(['one',2.11,3j,4,5],index=[0,1,2,3,4])

# %%
print(a1)
# Out:
# 0     one
# 1    2.11
# 2      3j
# 3       4
# 4       5
# dtype: object

# %%
season={"rainy":{1:'nov',2:'dec',3:'jan',4:'feb'},"dry":{1:'mar',2:'apr',3:'may',4:'jun'},"winter":{1:'july',2:'aug',3:'sep',4:'oct'}}

# %%
d=pd.DataFrame(season,columns=["rainy","dry","winter"])

# %%
d
# Out:
#   rainy  dry winter
# 1   nov  mar   july
# 2   dec  apr    aug
# 3   jan  may    sep
# 4   feb  jun    oct

# %%
import numpy as np

# %%
a=pd.DataFrame(np.random.randint(-10,10,size=(25,5)),columns=list('abcde'))

# %%
a
# Out:
#     a   b   c   d  e
# 0   9   8   3   7 -9
# 1   0  -1   8  -7  5
# 2   8 -10   0  -7  5
# 3   3   1   3   3 -3
# 4   6   0   0   4  1
# 5   9  -4 -10  -2 -4
# 6   5   2  -7   7 -9
# 7   4   6   6   0  7
# 8   5  -1 -10   2  9
# 9  -7   6   5 -10  2
# 10 -3  -9  -2   2  0
# 11  4  -4   6  -8 -4
# 12  7   5  -9  -2 -3
# 13 -7  -7  -9  -9 -4
# 14 -6 -10   4   3  0
# 15 -5  -5   7   2  3
# 16  3   5   5  -1  1
# 17  2  -1  -4   2  6
# 18  7   5   5  -2 -4
# 19 -6  -2   6   1  8
# 20  3   5   7  -1 -3
# 21  0  -1   5   6 -8
# 22 -1   9   8 -10 -5
# 23  8   3  -4  -8  6
# 24  2 -10  -4   2  5

# %%
a.to_csv('C:/Users/Admin/Documents/VIKKI 4TH/Pandas.csv')

# %%
d=pd.read_csv('C:/Users/Admin/Documents/VIKKI 4TH/Pandas.csv')

# %%
print(d)
# Out:
#     Unnamed: 0  a   b   c   d  e
# 0            0  9   8   3   7 -9
# 1            1  0  -1   8  -7  5
# 2            2  8 -10   0  -7  5
# 3            3  3   1   3   3 -3
# 4            4  6   0   0   4  1
# 5            5  9  -4 -10  -2 -4
# 6            6  5   2  -7   7 -9
# 7            7  4   6   6   0  7
# 8            8  5  -1 -10   2  9
# 9            9 -7   6   5 -10  2
# 10          10 -3  -9  -2   2  0
# 11          11  4  -4   6  -8 -4
# 12          12  7   5  -9  -2 -3
# 13          13 -7  -7  -9  -9 -4
# 14          14 -6 -10   4   3  0
# 15          15 -5  -5   7   2  3
# 16          16  3   5   5  -1  1
# 17          17  2  -1  -4   2  6
# 18          18  7   5   5  -2 -4
# 19          19 -6  -2   6   1  8
# 20          20  3   5   7  -1 -3
# 21          21  0  -1   5   6 -8
# 22          22 -1   9   8 -10 -5
# 23          23  8   3  -4  -8  6
# 24          24  2 -10  -4   2  5

# %%
d.drop("Unnamed: 0",axis=1)
# Out:
#     a   b   c   d  e
# 0   9   8   3   7 -9
# 1   0  -1   8  -7  5
# 2   8 -10   0  -7  5
# 3   3   1   3   3 -3
# 4   6   0   0   4  1
# 5   9  -4 -10  -2 -4
# 6   5   2  -7   7 -9
# 7   4   6   6   0  7
# 8   5  -1 -10   2  9
# 9  -7   6   5 -10  2
# 10 -3  -9  -2   2  0
# 11  4  -4   6  -8 -4
# 12  7   5  -9  -2 -3
# 13 -7  -7  -9  -9 -4
# 14 -6 -10   4   3  0
# 15 -5  -5   7   2  3
# 16  3   5   5  -1  1
# 17  2  -1  -4   2  6
# 18  7   5   5  -2 -4
# 19 -6  -2   6   1  8
# 20  3   5   7  -1 -3
# 21  0  -1   5   6 -8
# 22 -1   9   8 -10 -5
# 23  8   3  -4  -8  6
# 24  2 -10  -4   2  5

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
data = {'PLAYERS':['leo','Neymarjr','salah','yamal'],'RATINGS':[10,8,9,8],'CLUBS':['FCB','PSG','LFC','FCB']}

# %%
g=pd.DataFrame(data,columns=['PLAYERS','RATINGS','CLUBS'])

# %%
g
# Out:
#     PLAYERS  RATINGS CLUBS
# 0       leo       10   FCB
# 1  Neymarjr        8   PSG
# 2     salah        9   LFC
# 3     yamal        8   FCB

# %%
random = pd.DataFrame(np.random.randint(100,500,size=(40,5)),columns=list('ABCDE'))

# %% [markdown]
# random

# %% [markdown]
# # Data Normalization

# %%
normalization_df=pd.DataFrame({'x':np.random.randint(-100,100,1000),
                   'y':np.random.randint(-80,80,1000),
                   'z':np.random.randint(-150,100,1000)})

# %%
normalization_df
# Out:
#       x   y   z
# 0    55 -26  82
# 1   -81 -24 -16
# 2    35  60 -39
# 3   -29 -12  43
# 4   -92  55   1
# ..   ..  ..  ..
# 995  49 -11 -58
# 996  29  37  92
# 997  94   8  -1
# 998 -76  29   9
# 999  45 -30 -88
#
# [1000 rows x 3 columns]

# %%
ax= plt.axes(projection='3d')

ax.scatter3D(normalization_df.x,normalization_df.y,normalization_df.z)

plt.figure()
